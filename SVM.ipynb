# %%
import pandas as pd
from scipy.io import loadmat
import numpy as np
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from utilities import remove_empty_tweets

# %%
train_data_path = 'cleaned_data/cleaned_train_data_for_subtask1.csv'
test_data_path = 'cleaned_data/cleaned_test_data_for_subtask1.csv'
#read files.
train_data = pd.read_csv(train_data_path)
test_data = pd.read_csv(test_data_path)

print("Train set:"% train_data.columns, train_data.shape, len(train_data)) 
print("Test set:"% test_data.columns, test_data.shape, len(test_data))
# Out:
# Train set: (20974, 8) 20974
# Test set: (4997, 8) 4997

# %%
train_data = remove_empty_tweets(train_data, "#2_tweet_clean_V1")
test = remove_empty_tweets(test_data, "#2_tweet_clean_V1")

train_data.head()
# Out:
#   #1_tweetid                                           #2_tweet  \
# 0    TRAIN_0                                     حاجة حلوة اكيد
# 1    TRAIN_1  عم بشتغلوا للشعب الاميركي اما نحن يكذبوا ويغشو...
# 2    TRAIN_2                                      ابشر طال عمرك
# 3    TRAIN_3  منطق 2017: أنا والغريب علي إبن عمي وأنا والغري...
# 4    TRAIN_4                  شهرين وتروح والباقي غير صيف ملينا
#
#   #3_country_label                                  #2_tweet_clean_V0  \
# 0            Egypt                                     حاجة حلوة اكيد
# 1             Iraq  عم بشتغلوا للشعب الاميركي اما نحن يكذبوا ويغشو...
# 2     Saudi_Arabia                                      ابشر طال عمرك
# 3       Mauritania  منطق  أنا والغريب علي إبن عمي وأنا والغريب وإب...
# 4          Algeria                  شهرين وتروح والباقي غير صيف ملينا
#
#                                    #2_tweet_clean_V1  \
# 0                                     حاجه حلوه اكيد
# 1  عم بشتغلوا لشعب الاميركي اما نحن يكذبوا ويغشوا...
# 2                                      ابشر طال عمرك
# 3  منطق انا والغريب علي ابن عمي وانا والغريب وابن...
# 4                  شهرين وتروح والباقي غير صيف ملينا
#
#                                    #2_tweet_clean_V2  \
# 0                                     حاجه حلوه اكيد
# 1  عم بشتغلوا لشعب الاميركي يكذبوا ويغشوا ويسرقوا...
# 2                                      ابشر طال عمرك
# 3  منطق والغريب ابن عمي وانا والغريب وابن عمي اخو...
# 4                      شهرين وتروح والباقي صيف ملينا
#
#                                    #2_tweet_clean_V3  #classes_id
# 0                                     حاجه حلوه اكيد            0
# 1  عم بشتغلوا لشعب الاميركي يكذبوا ويغشوا ويسرقوا...            1
# 2                                      ابشر طال عمرك            2
# 3  منطق والغريب ابن عمي وانا وابن اخويا قطع العلا...            3
# 4                      شهرين وتروح والباقي صيف ملينا            4

# %%
#prepare train and test data.
X_train = train_data['#2_tweet_clean_V1'].tolist()
y_train = train_data['#classes_id'].tolist()
X_test = test_data['#2_tweet_clean_V1'].tolist()
y_test = test_data['#classes_id'].tolist()

# %%
x_train, x_valid, y_train, y_valid = model_selection.train_test_split(train_data['#2_tweet_clean_V1'],train_data['#classes_id'],test_size=0.3, random_state=42)

print(len(x_train),len(x_valid))
# Out:
# 14681 6293

# %%
#Create vocabulary

Tfidf_vect = TfidfVectorizer(max_features=5000, ngram_range=(1,3), stop_words=STOPWORDS)
Tfidf_vect.fit(train_data['#2_tweet_clean_V1'])
Train_X_Tfidf = Tfidf_vect.transform(x_train)
Test_X_Tfidf = Tfidf_vect.transform(x_valid)

print(Tfidf_vect.vocabulary_)
# Out:
# {'حاجه': 2001, 'حلوه': 2127, 'اكيد': 350, 'حاجه حلوه': 2002, 'عم': 2977, 'اما': 1128, 'نحن': 4181, 'طال': 2786, 'عمرك': 2982, 'طال عمرك': 2787, 'انا': 1165, 'علي': 2961, 'ابن': 19, 'عمي': 2997, 'وانا': 4451, 'وابن': 4378, 'اخويا': 134, 'قطع': 3287, 'العلاقات': 795, 'مع': 3915, 'قطر': 3286, 'موريتانيا': 4116, 'شهرين': 2665, 'والباقي': 4417, 'غير': 3074, 'صيف': 2768, 'ملينا': 4008, 'واله': 4431, 'ما': 3660, 'حد': 2049, 'ولا': 4603, 'منك': 4081, 'انتى': 1222, 'اساسا': 181, 'واله ما': 4442, 'ما حد': 3672, 'نفس': 4221, 'الوقت': 1086, 'على': 2941, 'ان': 1156, 'اي': 1312, 'هدف': 4303, 'دايما': 2248, 'عشان': 2902, 'نفسنا': 4225, 'الفاضي': 834, 'نفس الوقت': 4222, 'خرا': 2179, 'بقا': 1561, 'علشان': 2937, 'عليكي': 2970, 'نفسك': 4224, 'دخل': 2249, 'هو': 4347, 'حلو': 2124, 'بس': 1490, 'ليك': 3649, 'عدنا': 2880, 'حلو بس': 2126, 'بصراحه': 1520, 'مسلسل': 3872, 'هيك': 4372, 'بتذكر': 1423, 'كان': 3342, 'اسمها': 209, 'في': 3167, 'احمد': 99, 'ربي': 2383, 'كي': 3475, 'يجي': 4802, 'واحد': 4385, 'منهم': 4086, 'واحد منهم': 4389, 'يسطا': 4872, 'لازم': 3516, 'قريب': 3276, 'خد': 2174, 'بالك': 1400, 'خد بالك': 2175, 'اله': 1011, 'لو': 3616, 'راسي': 2348, 'مال': 3737, 'صور': 2762, 'تاريخ': 1678, 'نوع': 4262, 'الجزار': 511, 'في الجزار': 3172, 'لا': 3490, 'اني': 1256, 'بدو': 1461, 'بين': 1664, 'البنات': 465, 'فعلا': 3139, 'جمله': 1959, 'لكل': 3588, 'فعل': 3138, 'رد': 2401, 'يعنى': 4923, 'اكثر': 336, 'يوم': 4991, 'حسيت': 2080, 'فيه': 3222, 'ولكن': 4626, 'المستقبل': 939, 'راه': 2360, 'اول': 1296, 'كاس': 3334, 'افريقيا': 304, 'بجد': 1432, 'القب': 866, 'اموت': 1150, 'وش': 4547, 'ذا': 2314, 'بالي': 1406, 'حب': 2021, 'واني': 4473, 'ادري': 146, 'انه': 1246, 'صعب': 2750, 'شنو': 2660, 'في بالي': 3183, 'انا في': 1183, 'لما': 3594, 'اقول': 322, 'لبنت': 3542, 'دي': 2304, 'مش': 3878, 'دا': 2235, 'عظيم': 2919, 'الي': 1093, 'عليها': 2975, 'كده': 3372, 'بعد': 1533, 'الحوار': 580, 'لي': 3634, 'البارح': 442, 'حصه': 2086, 'وان': 4448, 'لن': 3604, 'ولن': 4628, 'من': 4011, 'بحبها': 1439, 'جدا': 1931, 'فيها': 3223, 'خرافي': 2180, 'اي واله': 1319, 'او': 1283, 'الزواج': 646, 'كل': 3397, 'ذيل': 2330, 'وكل': 4598, 'ولكم': 4625, 'حبك': 2023, 'ارجع': 164, 'احبك': 68, 'جديد': 1939, 'من جديد': 4037, 'ولا انا': 4604, 'احسن': 84, 'اعيط': 293, 'المذاكره': 930, 'عليا': 2962, 'الجزيره': 513, 'ياريت': 4751, 'يطلع': 4904, 'دفع': 2266, 'ال': 351, 'فلم': 3151, 'مدري': 3822, 'نزل': 4191, 'اسبوعين': 188, 'ادور': 150, 'عليه': 2973, 'اتوقع': 50, 'اسمه': 208, 'كيف': 3478, 'اشوفه': 235, 'الهلال': 1057, 'الشباب': 690, 'هاردلك': 4282, 'الفريق': 847, 'مرحله': 3837, 'لعيبه': 3573, 'لعب': 3565, 'متاز': 3770, 'الشتويه': 693, 'بديل': 1465, 'مهاجم': 4097, 'جيد': 1994, 'بها': 1624, 'امتى': 1136, 'قعدت': 3288, 'صراحه': 2747, 'سال': 2491, 'وما': 4636, 'هي': 4362, 'زي': 2468, 'النوم': 1009, 'شي': 2684, 'غريب': 3063, 'الشوارع': 711, 'فاضيه': 3091, 'منذ': 4075, 'هل': 4328, 'مره': 3840, 'يعني': 4924, 'الارض': 384, 'الا': 354, 'الحقيقه': 556, 'ناس': 4147, 'كنت': 3463, 'انهم': 1250, 'كفو': 3396, 'ظني': 2822, 'يا': 4686, 'ريت': 2434, 'يا ريت': 4709, 'قويه': 3327, 'قدام': 3260, 'مخلوق': 3817, 'مثل': 3786, 'حبيتك': 2036, 'اقدر': 311, 'يغير': 4932, 'الغالي': 817, 'علاقه': 2934, 'شركه': 2622, 'كنتي': 3465, 'سب': 2499, 'يبارك': 4780, 'فيك': 3214, 'حبيب': 2027, 'قلبي': 3296, 'يبارك فيك': 4782, 'حبيب قلبي': 2028, 'فالفيردي': 3097, 'قبل': 3246, 'الماتش': 909, 'منها': 4085, 'يارب': 4747, 'اله لا': 1023, 'تاع': 1680, 'طفل': 2803, 'حتى': 2039, 'كاعد': 3337, 'خايف': 2170, 'انساك': 1233, 'تكون': 1860, 'مدن': 3825, 'الظروف': 761, 'غيرك': 3077, 'اشوف': 233, 'لكن': 3590, 'عندي': 3018, 'جو': 1979, 'هلبا': 4334, 'اسوا': 213, 'انك': 1241, 'تهون': 1878, 'ولو': 4630, 'اتغيرت': 42, 'كتير': 3363, 'كذا': 3376, 'اكثر من': 337, 'مت': 3767, 'العيون': 816, 'تحكم': 1723, 'ياما': 4769, 'يلا': 4960, 'ايش': 1335, 'اليوم': 1124, 'الى': 1091, 'سنتين': 2541, 'جات': 1912, 'وتقولي': 4494, 'اذا': 153, 'شخص': 2610, 'احس': 80, 'احس اني': 81, 'بس هو': 1501, 'وحده': 4506, 'الفيديو': 855, 'كامل': 3340, 'وعلي': 4572, 'مالها': 3742, 'غيري': 3081, 'يابنتي': 4734,  ...

# %%
test_X_Tfidf = Tfidf_vect.transform(X_test)

# %%
print(test_X_Tfidf)
# Out:
#   (0, 4686)	0.2725975949915372
#   (0, 3508)	0.6415376866873623
#   (0, 3490)	0.6003354275927336
#   (0, 2961)	0.3920680070366711
#   (2, 4834)	0.4806093873555371
#   (2, 4686)	0.22683678440777136
#   (2, 4624)	0.538938446041737
#   (2, 2380)	0.36145456538965853
#   (2, 919)	0.5444773994964055
#   (3, 4385)	0.3511588430380518
#   (3, 3610)	0.3744236716461203
#   (3, 3216)	0.5554519543228398
#   (3, 3013)	0.45440883178969727
#   (3, 2684)	0.33050102053802594
#   (3, 1312)	0.3350361122640352
#   (4, 4364)	0.59789450637883
#   (4, 2616)	0.6830940277353629
#   (4, 2039)	0.4194099528078635
#   (5, 4127)	0.4891438736639621
#   (5, 2702)	0.4982152879755282
#   (5, 2235)	0.3306280683541731
#   (5, 1347)	0.5220759805696495
#   (5, 1343)	0.2961330090818576
#   (5, 1165)	0.20723607201746264
#   (6, 4136)	0.7065462430350279
#   :	:
#   (4991, 1490)	0.36921557159185053
#   (4991, 1165)	0.33016595533171134
#   (4992, 3863)	0.6112193293814701
#   (4992, 3167)	0.29606537363679203
#   (4992, 692)	0.7340001538990116
#   (4993, 4601)	0.43970363937125917
#   (4993, 4455)	0.2895878848202753
#   (4993, 3484)	0.4316975946285373
#   (4993, 3292)	0.3473723436821818
#   (4993, 3167)	0.17918110822855912
#   (4993, 2816)	0.3666334872951275
#   (4993, 2029)	0.375891074206513
#   (4993, 350)	0.3285561213938112
#   (4994, 4874)	0.6460721902231467
#   (4994, 2711)	0.5795425721079425
#   (4994, 985)	0.49671031007497374
#   (4995, 3223)	1.0
#   (4996, 4431)	0.22378214846118433
#   (4996, 3868)	0.42433692078999913
#   (4996, 3490)	0.2079523701839666
#   (4996, 3025)	0.3786407330736708
#   (4996, 1187)	0.44444914085423776
#   (4996, 1165)	0.18663620833837807
#   (4996, 362)	0.37522031558265256
#   (4996, 193)	0.45835394225633136

# %% [markdown]
# #  Radial Basis Function  (RBF) kernel

# %%
import timeit

start = timeit.default_timer()

SVM = svm.SVC(C=1.0, kernel='rbf', degree=3, gamma=2)
SVM.fit(Train_X_Tfidf,y_train)

stop = timeit.default_timer()
print('Train time: ', stop - start)  

# predict the labels on validation dataset
predictions_SVM_valid = SVM.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM_valid, y_valid)*100)
# Out:
# Train time:  32.19084000000112
# SVM Accuracy Score ->  31.860797711743206

# %%
predictions_SVM = SVM.predict(test_X_Tfidf)

print(classification_report(predictions_SVM, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.31      0.47      3022
#            1       0.52      0.31      0.39      1108
#            2       0.24      0.26      0.25       488
#            3       0.00      0.00      0.00         0
#            4       0.19      0.46      0.27       177
#            5       0.04      0.26      0.07        42
#            6       0.04      0.19      0.07        72
#            7       0.02      0.60      0.03         5
#            8       0.01      0.33      0.01         3
#            9       0.02      0.40      0.04        10
#           10       0.00      0.00      0.00         2
#           11       0.01      0.17      0.01         6
#           12       0.02      0.50      0.04         4
#           13       0.06      0.38      0.10        47
#           14       0.00      0.00      0.00         0
#           15       0.00      0.00      0.00         0
#           16       0.01      0.50      0.02         2
#           17       0.00      0.00      0.00         9
#           18       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         0
#
#     accuracy                           0.31      4997
#    macro avg       0.10      0.22      0.08      4997
# weighted avg       0.70      0.31      0.40      4997

# %% [markdown]
# # Quadratic (poly) kernel

# %%
startquad = timeit.default_timer()

SVMquad = svm.SVC(C=1.0, kernel='poly', degree=3, gamma=2)
SVMquad.fit(Train_X_Tfidf,y_train)

stopquad = timeit.default_timer()
print('Train time: ', stopquad - startquad)  

# predict the labels on validation dataset
predictions_SVMquad = SVMquad.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVMquad, y_valid)*100)
# Out:
# Train time:  90.71464130000004
# SVM Accuracy Score ->  26.473859844271413

# %%
predictions_SVMquad_test = SVMquad.predict(test_X_Tfidf)

print(classification_report(predictions_SVMquad_test, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.27      0.41      3377
#            1       0.40      0.33      0.36       796
#            2       0.13      0.23      0.16       289
#            3       0.00      0.00      0.00         2
#            4       0.13      0.36      0.19       154
#            5       0.04      0.18      0.07        65
#            6       0.04      0.16      0.06        90
#            7       0.02      0.19      0.03        16
#            8       0.01      0.25      0.02         8
#            9       0.02      0.16      0.04        31
#           10       0.00      0.00      0.00         2
#           11       0.01      0.06      0.01        17
#           12       0.02      0.22      0.04         9
#           13       0.06      0.22      0.10        89
#           14       0.00      0.00      0.00         2
#           15       0.00      0.00      0.00         2
#           16       0.02      0.29      0.04         7
#           17       0.01      0.04      0.02        24
#           18       0.00      0.00      0.00         9
#           19       0.00      0.00      0.00         6
#           20       0.00      0.00      0.00         2
#
#     accuracy                           0.27      4997
#    macro avg       0.08      0.14      0.07      4997
# weighted avg       0.66      0.27      0.35      4997

# %%
print(classification_report(predictions_SVMquad, y_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.25      0.38      4368
#            1       0.39      0.35      0.37       942
#            2       0.09      0.21      0.13       261
#            3       0.00      0.00      0.00         0
#            4       0.19      0.43      0.26       247
#            5       0.03      0.13      0.04        76
#            6       0.06      0.22      0.09       115
#            7       0.05      0.37      0.09        35
#            8       0.01      0.18      0.03        17
#            9       0.03      0.24      0.05        34
#           10       0.03      0.33      0.06         6
#           11       0.01      0.08      0.02        26
#           12       0.04      0.38      0.08        13
#           13       0.07      0.24      0.11       109
#           14       0.00      0.00      0.00         1
#           15       0.00      0.00      0.00         3
#           16       0.00      0.00      0.00         9
#           17       0.02      0.18      0.03        11
#           18       0.00      0.00      0.00         7
#           19       0.16      0.64      0.25        11
#           20       0.02      0.50      0.03         2
#
#     accuracy                           0.26      6293
#    macro avg       0.10      0.22      0.10      6293
# weighted avg       0.67      0.26      0.34      6293
# C:\Users\maryam\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Linear kernel

# %%
startlin = timeit.default_timer()

SVMlin = svm.SVC(C=1.0, kernel='linear', degree=3, gamma=2)
SVMlin.fit(Train_X_Tfidf,y_train)

stoplin = timeit.default_timer()
print('Train time: ', stoplin - startlin)  

# predict the labels on validation dataset
predictions_SVMlin = SVMlin.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVMlin, y_valid)*100)
# Out:
# Train time:  55.940753599999994
# SVM Accuracy Score ->  37.86747179405689

# %%
predictions_SVMlin_test = SVMlin.predict(test_X_Tfidf)

print(classification_report(predictions_SVMlin_test, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.43      0.57      2034
#            1       0.51      0.32      0.39      1035
#            2       0.41      0.25      0.31       844
#            3       0.11      0.86      0.20         7
#            4       0.35      0.40      0.37       384
#            5       0.12      0.25      0.16       132
#            6       0.17      0.22      0.19       269
#            7       0.06      0.29      0.10        35
#            8       0.03      0.20      0.05        25
#            9       0.05      0.43      0.09        23
#           10       0.00      0.00      0.00         5
#           11       0.02      0.12      0.03        24
#           12       0.03      0.60      0.05         5
#           13       0.19      0.40      0.26       151
#           14       0.00      0.00      0.00         3
#           15       0.00      0.00      0.00         0
#           16       0.04      1.00      0.07         4
#           17       0.04      0.40      0.07        10
#           18       0.00      0.00      0.00         2
#           19       0.00      0.00      0.00         1
#           20       0.02      0.25      0.04         4
#
#     accuracy                           0.35      4997
#    macro avg       0.14      0.31      0.14      4997
# weighted avg       0.56      0.35      0.42      4997

# %%
print(classification_report(predictions_SVMlin, y_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.42      0.56      2555
#            1       0.54      0.35      0.42      1261
#            2       0.41      0.26      0.32       990
#            3       0.13      1.00      0.23        10
#            4       0.43      0.46      0.44       525
#            5       0.14      0.35      0.20       164
#            6       0.20      0.29      0.24       311
#            7       0.20      0.60      0.30        87
#            8       0.09      0.59      0.16        32
#            9       0.08      0.50      0.14        42
#           10       0.29      0.82      0.43        22
#           11       0.03      0.29      0.05        21
#           12       0.01      0.33      0.02         3
#           13       0.25      0.39      0.31       237
#           14       0.03      0.22      0.05         9
#           15       0.00      0.00      0.00         0
#           16       0.01      0.50      0.01         2
#           17       0.02      0.29      0.03         7
#           18       0.00      0.00      0.00         1
#           19       0.11      1.00      0.20         5
#           20       0.06      0.44      0.11         9
#
#     accuracy                           0.38      6293
#    macro avg       0.18      0.43      0.20      6293
# weighted avg       0.58      0.38      0.44      6293

# %% [markdown]
# # Sigmoid kernel

# %%
startsig = timeit.default_timer()

SVMsig = svm.SVC(C=1.0, kernel='sigmoid', degree=3, gamma=2)
SVMsig.fit(Train_X_Tfidf,y_train)

stopsig = timeit.default_timer()
print('Train time: ', stopsig - startsig)  

# predict the labels on validation dataset
predictions_SVMsig = SVMsig.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVMsig, y_valid)*100)
# Out:
# Train time:  40.608465600000045
# SVM Accuracy Score ->  36.437311298267915

# %%
print(classification_report(predictions_SVMsig, y_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.42      0.56      2433
#            1       0.50      0.32      0.39      1268
#            2       0.39      0.25      0.30       976
#            3       0.13      1.00      0.23        10
#            4       0.41      0.43      0.42       526
#            5       0.13      0.29      0.18       181
#            6       0.19      0.25      0.22       342
#            7       0.20      0.56      0.30        96
#            8       0.12      0.43      0.19        58
#            9       0.09      0.36      0.14        64
#           10       0.32      0.80      0.46        25
#           11       0.04      0.24      0.07        34
#           12       0.01      0.20      0.02         5
#           13       0.23      0.38      0.29       232
#           14       0.03      0.22      0.05         9
#           15       0.00      0.00      0.00         0
#           16       0.01      0.17      0.01         6
#           17       0.02      0.25      0.03         8
#           18       0.00      0.00      0.00         3
#           19       0.09      1.00      0.16         4
#           20       0.12      0.62      0.21        13
#
#     accuracy                           0.36      6293
#    macro avg       0.18      0.39      0.20      6293
# weighted avg       0.54      0.36      0.42      6293
